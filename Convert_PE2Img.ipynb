# %%
from google.colab import drive
from os import path
import pandas as pd

import tensorflow as tf
from tensorflow.keras import layers, models, optimizers
from tensorflow.keras.utils import to_categorical

data_dir_name = 'Colab Notebooks'
drive.mount('/content/gdrive/')
data_base_dir = path.join('./gdrive/MyDrive/', data_dir_name)
if not path.exists(data_base_dir):
  print('Path Error!!!')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
f = open('/content/gdrive/MyDrive/Colab Notebooks/0a0afad8e8f344e0bc67dd683189abcc.exe', 'rb')

# %%
byte = f.read(1)
value = []
byte_array = []
while byte:
  value.append(ord(byte))
  byte_array.append(byte)
  byte = f.read(1)

# %%
print("length : ", len(value))
print("max : ", max(value))
print("min : ", min(value))
# Out:
# length :  739962
# max :  255
# min :  0

# %%
import math
print(math.sqrt(len(value)))
# Out:
# 860.210439369344

# %%
from PIL import Image

# %%
image = Image.new('L', (861, 861))

# %%
image.putdata(value)

# %%
image
# Out:
# <PIL.Image.Image image mode=L size=861x861 at 0x7F36C2897ED0>

# %%
image = Image.new('RGB', (861, 861))

# %%
image.putdata(value)

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=861x861 at 0x7F36C233D6D0>
